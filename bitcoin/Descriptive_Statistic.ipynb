# %%
import pandas as pd
import matplotlib.pyplot as plt

bitcoin_data = pd.read_csv('./BTC.csv')

# Calculating count
count = len(bitcoin_data)
print('Count:', count)

# Calculating max
max_price = max(bitcoin_data['Price'])
print('Max:', max_price)

# Calculating min
min_price = min(bitcoin_data['Price'])
print('Min:', min_price)

# Calculating the mean
mean_price = bitcoin_data['Price'].mean()
print('Mean:', mean_price)

# Calculating the median
median_price = bitcoin_data['Price'].median()
print('Median:', median_price)

# Calculating the mode
mode_price = bitcoin_data['Price'].mode()
print('Mode:', mode_price)

# Calculating the standard deviation
std_dev = bitcoin_data['Price'].std()
print('Standard Deviation:', std_dev)

# Calculating the coeficient of deviation
cv = std_dev / mean_price
print('Coefficient of Deviation:', cv)

# Calculating the variance
variance = bitcoin_data['Price'].var()
print('Variance:', variance)

# Calculating skewness
skewness = bitcoin_data['Price'].skew()
print('Skewness:', skewness)

# Calculating kurtosis
kurtosis = bitcoin_data['Price'].kurt()
print('Kurtosis:', kurtosis)

# Calculating the range
price_range = bitcoin_data['Price'].max() - bitcoin_data['Price'].min()
print('Range:', price_range)

# Calculating percentiles (0th, 25th, 50th, 75th, and 100th percentiles)
quantiles = bitcoin_data['Price'].quantile([0, 0.25, 0.5, 0.75, 1])
print('0th Percentile:', quantiles[0])
print('25th Percentile (Q1):', quantiles[0.25])
print('50th Percentile (Median):', quantiles[0.5])
print('75th Percentile (Q3):', quantiles[0.75])
print('100th Percentile:', quantiles[1])
# Out:
# Count: 2024
# Max: 67527.9
# Min: 3228.7
# Mean: 20636.363092885374
# Median: 12536.5
# Mode: 0     7196.4
# 1     7208.0
# 2     7530.8
# 3     9424.8
# 4     9529.6
# 5    16831.8
# 6    21365.2
# 7    21517.2
# Name: Price, dtype: float64
# Standard Deviation: 16230.558909178906
# Coefficient of Deviation: 0.786502875343116
# Variance: 263431042.50432676
# Skewness: 1.0060487835329976
# Kurtosis: -0.14647380777805674
# Range: 64299.2
# 0th Percentile: 3228.7
# 25th Percentile (Q1): 8072.475
# 50th Percentile (Median): 12536.5
# 75th Percentile (Q3): 30228.85
# 100th Percentile: 67527.9

# %%
plt.figure(figsize=(10, 6))
plt.hist(bitcoin_data['Price'], bins=30, color='skyblue')
plt.title('Bitcoin Price Histogram')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(bitcoin_data['Price'], vert=True)
plt.title('Bitcoin Price Boxplot')
plt.ylabel('Price')
plt.show()
