# %%
import pandas as pd
import matplotlib.pyplot as plt

ethcoin_data = pd.read_csv('./ETH.csv')

# Calculating count
count = len(ethcoin_data)
print('Count:', count)

# Calculating max
max_price = max(ethcoin_data['Price'])
print('Max:', max_price)

# Calculating min
min_price = min(ethcoin_data['Price'])
print('Min:', min_price)

# Calculating the mean
mean_price = ethcoin_data['Price'].mean()
print('Mean:', mean_price)

# Calculating the median
median_price = ethcoin_data['Price'].median()
print('Median:', median_price)

# Calculating the mode
mode_price = ethcoin_data['Price'].mode()
print('Mode:', mode_price)

# Calculating the standard deviation
std_dev = ethcoin_data['Price'].std()
print('Standard Deviation:', std_dev)

# Calculating the coeficient of deviation
cv = std_dev / mean_price
print('Coefficient of Deviation:', cv)

# Calculating the variance
variance = ethcoin_data['Price'].var()
print('Variance:', variance)

# Calculating skewness
skewness = ethcoin_data['Price'].skew()
print('Skewness:', skewness)

# Calculating kurtosis
kurtosis = ethcoin_data['Price'].kurt()
print('Kurtosis:', kurtosis)

# Calculating the range
price_range = ethcoin_data['Price'].max() - ethcoin_data['Price'].min()
print('Range:', price_range)

# Calculating percentiles (0th, 25th, 50th, 75th, and 100th percentiles)
quantiles = ethcoin_data['Price'].quantile([0, 0.25, 0.5, 0.75, 1])
print('0th Percentile:', quantiles[0])
print('25th Percentile (Q1):', quantiles[0.25])
print('50th Percentile (Median):', quantiles[0.5])
print('75th Percentile (Q3):', quantiles[0.75])
print('100th Percentile:', quantiles[1])
# Out:
# Count: 2024
# Max: 4808.38
# Min: 83.81
# Mean: 1185.05104743083
# Median: 674.4000000000001
# Mode: 0      107.90
# 1      118.23
# 2      125.24
# 3      132.92
# 4      135.72
# 5      137.92
# 6      144.01
# 7      148.89
# 8      163.47
# 9      164.36
# 10     173.00
# 11     179.87
# 12     181.11
# 13     196.14
# 14     206.62
# 15     212.00
# 16     225.63
# 17     229.15
# 18     231.87
# 19     241.26
# 20     591.09
# 21    1047.00
# 22    1323.41
# 23    1818.07
# 24    2229.53
# Name: Price, dtype: float64
# Standard Deviation: 1154.2231569143723
# Coefficient of Deviation: 0.9739860231478702
# Variance: 1332231.0959573798
# Skewness: 1.086332419816677
# Kurtosis: 0.2626828439718478
# Range: 4724.57
# 0th Percentile: 83.81
# 25th Percentile (Q1): 219.8275
# 50th Percentile (Median): 674.4000000000001
# 75th Percentile (Q3): 1815.79
# 100th Percentile: 4808.38

# %%
plt.figure(figsize=(10, 6))
plt.hist(ethcoin_data['Price'], bins=30, color='skyblue')
plt.title('Ethereum Price Histogram')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(ethcoin_data['Price'], vert=True)
plt.title('Ethereum Price Boxplot')
plt.ylabel('Price')
plt.show()
